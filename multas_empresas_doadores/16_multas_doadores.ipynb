# %%
# -*- coding: utf-8
# Repórter Brasil (https://ruralometro2022.reporterbrasil.org.br/)
# Reinaldo Chaves (@paidatocandeira)
# Lista os IDs dos doadores de deputados inscritos nas listas de irregularidades do projeto, eliminando 
# repetições
# Lista as empresas dos doadores, a partir dos IDs
# Verifica se as empresas estão nas listas de irregularidades

# %%
import pandas as pd
from datetime import datetime
import unidecode

# %%
def f(str):
    try:
        return (unidecode.unidecode(str))
    except:
        return (str)

# %%
# Doações diretas vindas de inscritos com embargos no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_1 = pd.read_csv("resultados/embargos_ibama/doacoes_vindas_pessoas_com_embargos_ibama_2018.csv", **kwargs)

# %%
doacoes_1.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_nome', 'doacoes_tipo',
#        'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_1_dep = doacoes_1[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_1 = doacoes_1[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações indiretas vindas de inscritos com embargos no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_2 = pd.read_csv("resultados/embargos_ibama/doacoes_indiretas_vindas_pessoas_com_embargos_ibama_2018.csv", **kwargs)

# %%
doacoes_2.columns
# Out:
# Index(['valor', 'politico_id', 'politico_id.1', 'entidade_id', 'entidade_nome',
#        'sequencialdoador_id', 'doacoes_tipo', 'origem_do_dinheiro_no_tse',
#        'data'],
#       dtype='object')

# %%
doacoes_2_dep = doacoes_2[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_2 = doacoes_2[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações originárias vindas de inscritos com embargos no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_3 = pd.read_csv("resultados/embargos_ibama/doacoes_originarias_vindas_pessoas_com_embargos_ibama_2018.csv", **kwargs)

# %%
doacoes_3.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_nome', 'doacoes_tipo',
#        'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_3_dep = doacoes_3[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_3 = doacoes_3[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações diretas vindas de inscritos com autos de infração no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_4 = pd.read_csv("resultados/autos_ibama/doacoes_diretas_vindas_pessoas_com_autos_de_infracao_ibama_2018.csv", **kwargs)

# %%
doacoes_4.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_id_mascarada',
#        'entidade_nome', 'doacoes_tipo', 'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_4_dep = doacoes_4[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_4 = doacoes_4[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações indiretas vindas de inscritos com autos de infração no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_5 = pd.read_csv("resultados/autos_ibama/doacoes_indiretas_vindas_pessoas_com_autos_de_infracao_ibama_2018.csv", **kwargs)

# %%
doacoes_5.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_id_mascarada',
#        'entidade_nome', 'sequencialdoador_id', 'doacoes_tipo',
#        'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_5_dep = doacoes_5[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_5 = doacoes_5[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações originárias vindas de inscritos com autos no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_6 = pd.read_csv("resultados/autos_ibama/doacoes_originarias_vindas_pessoas_com_autos_ibama_2018.csv", **kwargs)

# %%
doacoes_6.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_id_mascarada',
#        'entidade_nome', 'doacoes_tipo', 'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_6_dep = doacoes_6[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_6 = doacoes_6[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações diretas vindas de inscritos com autos de infração no ICMBIO

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_7 = pd.read_csv("resultados/autos_icmbio/doacoes_vindas_pessoas_com_autos_icmbio_2018.csv", **kwargs)

# %%
doacoes_7.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_nome', 'doacoes_tipo',
#        'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_7_dep = doacoes_7[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_7 = doacoes_7[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
# Doações diretas vindas de inscritos com autos de infração trabalhistas

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_8 = pd.read_csv("resultados/autos_mte/doacoes_diretas_vindas_pessoas_com_autos_de_mte_2018.csv", **kwargs)

# %%
doacoes_8.columns
# Out:
# Index(['valor', 'politico_id', 'entidade_id', 'entidade_nome', 'doacoes_tipo',
#        'origem_do_dinheiro_no_tse', 'data'],
#       dtype='object')

# %%
doacoes_8_dep = doacoes_8[['entidade_id', 'entidade_nome', 'doacoes_tipo', 'politico_id']]

# %%
doacoes_8.shape
# Out:
# (138, 7)

# %%
doacoes_8 = doacoes_8[['entidade_id', 'entidade_nome', 'doacoes_tipo']]

# %%
frames = [doacoes_1, doacoes_2, doacoes_3, doacoes_4, doacoes_5, doacoes_6, doacoes_7, doacoes_8] 
todas_doacoes = pd.concat(frames)
todas_doacoes['cpf_mascarado']= '***'+todas_doacoes['entidade_id'].str[3:9]+'**'

todas_doacoes["entidade_nome"] = todas_doacoes["entidade_nome"].str.upper()
todas_doacoes["entidade_nome"] = todas_doacoes["entidade_nome"].apply(f)

todas_doacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 587 entries, 0 to 137
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   entidade_id    587 non-null    object
#  1   entidade_nome  587 non-null    object
#  2   doacoes_tipo   587 non-null    object
#  3   cpf_mascarado  587 non-null    object
# dtypes: object(4)
# memory usage: 22.9+ KB

# %%
frames = [doacoes_1_dep, doacoes_2_dep, doacoes_3_dep, doacoes_4_dep, doacoes_5_dep, doacoes_6_dep, doacoes_7_dep, doacoes_8_dep] 
todas_doacoes_dep = pd.concat(frames)
todas_doacoes_dep['cpf_mascarado']= '***'+todas_doacoes_dep['entidade_id'].str[3:9]+'**'

todas_doacoes_dep["entidade_nome"] = todas_doacoes_dep["entidade_nome"].str.upper()
todas_doacoes_dep["entidade_nome"] = todas_doacoes_dep["entidade_nome"].apply(f)

todas_doacoes_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 587 entries, 0 to 137
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   entidade_id    587 non-null    object
#  1   entidade_nome  587 non-null    object
#  2   doacoes_tipo   587 non-null    object
#  3   politico_id    587 non-null    object
#  4   cpf_mascarado  587 non-null    object
# dtypes: object(5)
# memory usage: 27.5+ KB

# %%
todas_doacoes_dep.head()
# Out:
#    entidade_id                   entidade_nome doacoes_tipo  politico_id  \
# 0  50913735272        ANAILTON FRANCA PINHEIRO       direta  65595564253
# 1  43334490220      JOSE RONALDO DE MATOS DIAS       direta  32770553291
# 2  18609287734  LUCIANO MAFFRA DE VASCONCELLOS       direta  79753566549
# 3  18609287734  LUCIANO MAFFRA DE VASCONCELLOS       direta  79753566549
# 4  34814396600     LUTZ VIANA RODRIGUES JUNIOR       direta  38247186500
#
#   cpf_mascarado
# 0   ***137352**
# 1   ***344902**
# 2   ***092877**
# 3   ***092877**
# 4   ***143966**

# %%
todas_doacoes_dep.to_excel('D://Code//RB//repo//rura2//resultados//downloads_site//todas_doacoes_com_cpfs_deputados.xlsx',sheet_name='Sheet1',index=False)

# %%
todas_doacoes = todas_doacoes.drop_duplicates(['cpf_mascarado', 'entidade_nome'], keep='first')
todas_doacoes.shape
# Out:
# (182, 4)

# %%
empresas_encontradas = todas_doacoes[(todas_doacoes['cpf_mascarado'] == '***836606**') &
                              (todas_doacoes['entidade_nome'] == 'RUBENS MENIN TEIXEIRA DE SOUZA')]
empresas_encontradas
# Out:
# Empty DataFrame
# Columns: [entidade_id, entidade_nome, doacoes_tipo, cpf_mascarado]
# Index: []

# %% [markdown]
# ### Empresas de doadores

# %%
TextFileReader = pd.read_csv('D://Code//nova_receita//socios_fev_2022.csv',\
                             chunksize=1000,\
                             sep=',',\
                             converters={'cnpj': lambda x: str(x),
                                         'cnpj_basico': lambda x: str(x)
                                        },\
                             usecols=['cnpj', 
                                      'cnpj_basico', 
                                      'identificador_de_socio', 
                                      'nome_socio', 
                                      'cnpj_cpf_socio', 
                                      'qualificacao_socio', 
                                      'pais',
                                      'representante_legal', 
                                      'nome_representante'])

# %%
now = datetime.now()
print("A extração começou às: ", now)

conta = 0
for df in TextFileReader:
    
    df["nome_socio"] = df["nome_socio"].str.upper()
    df["nome_socio"] = df["nome_socio"].apply(f)

    empresas_encontradas = pd.merge(todas_doacoes, \
                                 df, \
                                 left_on= ['cpf_mascarado', 'entidade_nome'],\
                                 right_on=['cnpj_cpf_socio', 'nome_socio'])
    
    if empresas_encontradas.empty is False:
        if conta == 0:
            df_socio1 = empresas_encontradas.copy()
        else:
            df_socio1 = pd.concat([df_socio1, empresas_encontradas])             
    
        conta = conta + 1
        
now = datetime.now()
print("A extração terminou às: ", now)
# Out:
# A extração começou às:  2022-08-10 10:01:22.819320
# A extração terminou às:  2022-08-10 10:03:51.511701

# %%
df_socio1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   entidade_id             1465 non-null   object
#  1   entidade_nome           1465 non-null   object
#  2   doacoes_tipo            1465 non-null   object
#  3   cpf_mascarado           1465 non-null   object
#  4   cnpj                    1465 non-null   object
#  5   cnpj_basico             1465 non-null   object
#  6   identificador_de_socio  1465 non-null   int64
#  7   nome_socio              1465 non-null   object
#  8   cnpj_cpf_socio          1465 non-null   object
#  9   qualificacao_socio      1465 non-null   int64
#  10  pais                    0 non-null      float64
#  11  representante_legal     1465 non-null   object
#  12  nome_representante      1 non-null      object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 160.2+ KB

# %%
df_socio1
# Out:
#     entidade_id                         entidade_nome doacoes_tipo  \
# 0   00279046871        SANDRO DA MABEL ANTONIO SCODRO       direta
# 0   92588298834        MARIO MAURICIO VASQUEZ BELTRAO       direta
# 0   37517678191                          IOAV BLANCHE       direta
# 0   47261897949                           CARLOS VIAN   originaria
# 0   37517678191                          IOAV BLANCHE       direta
# ..          ...                                   ...          ...
# 0   06451764949  CARLOS BENJAMIM MELO CORREA DA COSTA       direta
# 0   40567222004                          RICARDO LANG   originaria
# 0   17672538500              RAIMUNDO MAGALHAES COSTA       direta
# 1   02582430820                  JOAO CARLOS DI GENIO       direta
# 0   13773623453        GENTIL FERREIRA DE SOUZA FILHO       direta
#
#    cpf_mascarado            cnpj cnpj_basico  identificador_de_socio  \
# 0    ***790468**  32329476000167    32329476                       2
# ...

# %%
lista_cnpjs = df_socio1.drop_duplicates(['cnpj_basico'], keep='first')
lista_cnpjs.shape
# Out:
# (1435, 13)

# %%
lista_cnpjs = lista_cnpjs[['entidade_id', 'entidade_nome', 'cnpj', 'cnpj_basico', 'cpf_mascarado']]

# %%
lista_cnpjs
# Out:
#     entidade_id                         entidade_nome            cnpj  \
# 0   00279046871        SANDRO DA MABEL ANTONIO SCODRO  32329476000167
# 0   92588298834        MARIO MAURICIO VASQUEZ BELTRAO  05296337000101
# 0   37517678191                          IOAV BLANCHE  08029874000183
# 0   47261897949                           CARLOS VIAN  08209182000117
# 0   37517678191                          IOAV BLANCHE  08842831000112
# ..          ...                                   ...             ...
# 0   06451764949  CARLOS BENJAMIM MELO CORREA DA COSTA  02054530000148
# 0   40567222004                          RICARDO LANG  02648485000150
# 0   17672538500              RAIMUNDO MAGALHAES COSTA  06852558000181
# 1   02582430820                  JOAO CARLOS DI GENIO  02914675000171
# 0   13773623453        GENTIL FERREIRA DE SOUZA FILHO  08058802000164
#
#    cnpj_basico cpf_mascarado
# 0     32329476   ***790468**
# 0     05296337   ***882988**
# 0     08029874   ***176781**
# ...

# %%
empresas_encontradas = lista_cnpjs[(lista_cnpjs['cpf_mascarado'] == '***836606**') &
                              (lista_cnpjs['entidade_nome'] == 'RUBENS MENIN TEIXEIRA DE SOUZA')]
empresas_encontradas
# Out:
# Empty DataFrame
# Columns: [entidade_id, entidade_nome, cnpj, cnpj_basico, cpf_mascarado]
# Index: []

# %% [markdown]
# ### Multas trabalhistas

# %%
kwargs = {'sep': ';', 'dtype': str, 'encoding': 'utf-8'}
autos_mte = pd.read_csv("originais/autos_mte_10anos.csv", **kwargs)

autos_mte = autos_mte[pd.notnull(autos_mte['cpf_cnpj_infrator'])]

def limpeza1(linha):
    documento = str(linha["cpf_cnpj_infrator"])
    documento = documento.strip()
    documento = documento.replace('.', '')
    documento = documento.replace('-', '')
    documento = documento.replace('/', '')
    return str(documento)
autos_mte["cpf_cnpj_infrator"] = autos_mte.apply(limpeza1, axis=1)

# Preenche zeros a esquerda nos documentos
def compara1(linha):
    documento = str(linha["cpf_cnpj_infrator"])
    
    if len(documento) < 14 and len(documento) >= 12:
        conta = 14 - (len(documento))
        zero = '0'
        zeros = zero * conta
        alterado = zeros + documento
    elif len(documento) == 14:
        alterado = documento
    elif len(documento) < 11:
        conta = 11 - (len(documento))
        zero = '0'
        zeros = zero * conta
        alterado = zeros + documento
    elif len(documento) == 11:
        alterado = documento
    
    return alterado
autos_mte["cpf_cnpj_infrator"] = autos_mte.apply(compara1, axis=1)

def limpeza2(linha):
    documento = str(linha["cpf_cnpj_infrator"])
    if len(documento) > 11:
        return documento[:8]
    else:
        return "documento_cpf"

autos_mte['cnpj_raiz'] = autos_mte.apply(limpeza2, axis=1)

# %%
autos_mte.columns
# Out:
# Index(['num_processo', 'cpf_cnpj_infrator', 'tipo_infracao', 'capitulacao',
#        'valor_multa', 'data', 'reincidencia', 'cnpj_raiz'],
#       dtype='object')

# %%
autos_mte
# Out:
#                  num_processo cpf_cnpj_infrator  \
# 0        04623.600976/2019-29    01478313000112
# 1        04630.000684/2012-26    76483726001832
# 2        04646.600012/2014-16    07352882000101
# 3        04667.000284/2019-70    04084451000105
# 4        04678.401163/2015-99    07102206000171
# ...                       ...               ...
# 1048570  46254.003192/2017-81    09622736000176
# 1048571  46254.003192/2019-43    27733974000130
# 1048572  46254.003193/2012-11    12542573000126
# 1048573  46254.003193/2014-83    00831373003804
# 1048574  46254.003193/2015-64    08893267000167
#
#                                              tipo_infracao  \
# 0                                                     FGTS
# 1                                             NR 05 - CIPA
# 2                                     Períodos de descanso
# 3                                    Registro de empregado
# 4        NR 18 - Condições e Meio Ambiente de Trabalho ...
# ...

# %%
empresas_mte = pd.merge(lista_cnpjs, autos_mte.drop_duplicates('cnpj_raiz'), left_on='cnpj_basico', right_on='cnpj_raiz', how = 'left')

# %%
conta = empresas_mte[pd.notnull(empresas_mte['cpf_cnpj_infrator'])].copy()
conta.shape
# Out:
# (76, 13)

# %%
conta.head()
# Out:
#      entidade_id             entidade_nome            cnpj cnpj_basico  \
# 11   31215203691    WALTER SANTANA ARANTES  09599852000111    09599852
# 103  62594370215   HELDER ZAHLUTH BARBALHO  04885828000125    04885828
# 110  26695806888            ARIEL HOROVITZ  11902798000183    11902798
# 115  03577163887  JOSE RIBEIRO DE MENDONCA  33277096000199    33277096
# 127  02582430820      JOAO CARLOS DI GENIO  43144138000177    43144138
#
#     cpf_mascarado          num_processo cpf_cnpj_infrator  \
# 11    ***152036**  46246.001603/2012-99    09599852000111
# 103   ***943702**  46222.002738/2015-92    04885828000125
# 110   ***958068**  46224.000911/2015-06    11902798000183
# 115   ***771638**  46208.000132/2015-09    33277096000199
# 127   ***824308**  46219.003199/2012-15    43144138000177
#
#                         tipo_infracao  \
# 11                               FGTS
# 103                              FGTS
# 110                      Fiscalização
# ...

# %%
baixa = conta[['entidade_id', 'entidade_nome', 'cnpj', 'cnpj_basico', 'cpf_mascarado']]

# %%
TextFileReader = pd.read_csv('D://Code//nova_receita//empresas_fev_2022.csv',\
                             chunksize=1000,\
                             sep=',',\
                             converters={'cnpj_basico': lambda x: str(x)},\
                             usecols=['cnpj_basico', 
                                      'razao_social'])

# %%
now = datetime.now()
print("A extração começou às: ", now)

conta = 0
for df in TextFileReader:

    empresas_encontradas = pd.merge(baixa, \
                                 df, \
                                 left_on= 'cnpj_basico', \
                                 right_on='cnpj_basico')
    
    if empresas_encontradas.empty is False:
        if conta == 0:
            df_empresas1 = empresas_encontradas.copy()
        else:
             df_empresas1 = pd.concat([df_empresas1, empresas_encontradas])             
    
        conta = conta + 1
        
now = datetime.now()
print("A extração terminou às: ", now)
# Out:
# A extração começou às:  2022-08-09 09:38:45.412816
# A extração terminou às:  2022-08-09 09:42:43.249768

# %%
df_empresas1.sample(5)
# Out:
#    entidade_id            entidade_nome            cnpj cnpj_basico  \
# 0  02582430820     JOAO CARLOS DI GENIO  11918109000129    11918109
# 0  13205285115        MAGDA MOFATTO HON  02167740000142    02167740
# 0  02582430820     JOAO CARLOS DI GENIO  31300858000103    31300858
# 0  01754580904  ANTONIO CELSO SGANZERLA  83297515000122    83297515
# 0  28638042000            NESTOR MULLER  87246179000140    87246179
#
#   cpf_mascarado                                       razao_social
# 0   ***824308**              AESA ENSINO SUPERIOR DE ALAGOAS LTDA.
# 0   ***052851**                        THERMAS DI ROMA HOTEL CLUBE
# 0   ***824308**             AVIES ENSINO SUPERIOR DE VITORIA LTDA.
# 0   ***545809**                               CELTE NAVEGACAO LTDA
# 0   ***380420**  ABASTECEDORA DE COMBUSTIVEIS E DERIVADOS PINGU...

# %%
df_empresas1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   entidade_id    76 non-null     object
#  1   entidade_nome  76 non-null     object
#  2   cnpj           76 non-null     object
#  3   cpf_mascarado  76 non-null     object
#  4   cnpj_nome      76 non-null     object
# dtypes: object(5)
# memory usage: 3.6+ KB

# %%
df_empresas1.rename(columns = {'razao_social':'cnpj_nome'},inplace = True)
df_empresas1.drop('cnpj_basico', axis=1, inplace=True)

# %%
df_empresas1.to_csv('resultados/autos_mte/empresas_de_doadores_com_autos_trabalhistas_8ago.csv',index=False)

# %%
df_empresas1.to_excel('resultados/autos_mte/empresas_de_doadores_com_autos_trabalhistas_8ago.xlsx',sheet_name='Sheet1',index=False)

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
politicos = pd.read_csv("resultados/politicos_2018_versao_26jul_2022.csv", **kwargs)

# %%
politicos.columns
# Out:
# Index(['nome', 'foto', 'nome_urna', 'uf_eleicao_disputa', 'politico_id', 'uri',
#        'sequencial_candidato', 'bancada_ruralista', 'id_interno',
#        'doacao_ambiental_direta_total', 'doacao_ambiental_indireta_total',
#        'doacao_ambiental_originaria_total', 'doacao_trabalhista_direta_total',
#        'total_geral_doacoes_diretas', 'total_geral_doacoes_indiretas',
#        'total_geral_doacoes_originarias', 'temperatura_ruralometro_2018',
#        'partido_atual'],
#       dtype='object')

# %%
procura_politicos = pd.merge(df_empresas1, politicos, left_on='entidade_id', right_on='politico_id')

# %%
procura_politicos
# Out:
#    entidade_id                    entidade_nome            cnpj cpf_mascarado  \
# 0  01960970453            LUIZ GONZAGA PATRIOTA  00044180000103   ***609704**
# 1  13205285115                MAGDA MOFATTO HON  00071556000179   ***052851**
# 2  13205285115                MAGDA MOFATTO HON  01753713000199   ***052851**
# 3  13205285115                MAGDA MOFATTO HON  02167740000142   ***052851**
# 4  13205285115                MAGDA MOFATTO HON  03465317000191   ***052851**
# 5  13205285115                MAGDA MOFATTO HON  12947899000133   ***052851**
# 6  37788566349  MARCOS ROBERIO RIBEIRO MONTEIRO  03719327000106   ***885663**
#
#                                    cnpj_nome                             nome  \
# 0                         CLUBE DO CONGRESSO            LUIZ GONZAGA PATRIOTA
# 1             ROMA HOTEIS E REALIZACOES LTDA                MAGDA MOFATTO HON
# 2  DI ROMA EMPREENDIMENTOS IMOBILIARIOS LTDA                MAGDA MOFATTO HON
# ...

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
doacoes_2018 = pd.read_csv("resultados/doacoes/doacoes_geral_politicos_2018.csv", **kwargs)

doacoes_2018['VR_RECEITA'] = doacoes_2018['VR_RECEITA'].str.replace(',','.')
doacoes_2018['VR_RECEITA'] = doacoes_2018['VR_RECEITA'].astype('float64') 

def limpeza5(linha):
    documento = str(linha["NR_CPF_CNPJ_DOADOR"])
    if len(documento) > 11:
        return documento[:8]
    else:
        return documento

doacoes_2018['doador_raiz'] = doacoes_2018.apply(limpeza5, axis=1)

# %%
doacoes_2018.columns
# Out:
# Index(['DT_RECEITA', 'NR_CPF_CANDIDATO', 'SQ_CANDIDATO', 'NM_CANDIDATO',
#        'DS_FONTE_RECEITA', 'DS_NATUREZA_RECEITA', 'NR_CPF_CNPJ_DOADOR',
#        'NM_DOADOR_RFB', 'DS_ESFERA_PARTIDARIA_DOADOR', 'NM_PARTIDO_DOADOR',
#        'SQ_CANDIDATO_DOADOR', 'DS_CARGO_CANDIDATO_DOADOR', 'SG_PARTIDO_DOADOR',
#        'DS_RECEITA', 'VR_RECEITA', 'doador_raiz'],
#       dtype='object')

# %%
doacoes_elesmesmos = doacoes_2018[(doacoes_2018['NR_CPF_CANDIDATO'] == '33096473234') |
                              (doacoes_2018['NR_CPF_CANDIDATO'] == '01960970453') | 
                                  (doacoes_2018['NR_CPF_CANDIDATO'] == '13205285115') | 
                                  (doacoes_2018['NR_CPF_CANDIDATO'] == '37788566349') 
                                 ]

# %%
doacoes_elesmesmos = doacoes_elesmesmos[(doacoes_elesmesmos['NR_CPF_CNPJ_DOADOR'] == '33096473234') |
                              (doacoes_elesmesmos['NR_CPF_CNPJ_DOADOR']  == '01960970453') | 
                                 (doacoes_elesmesmos['NR_CPF_CNPJ_DOADOR']  == '13205285115') | 
                                  (doacoes_elesmesmos['NR_CPF_CNPJ_DOADOR'] == '37788566349') 
                                 ]

# %%
doacoes_elesmesmos
# Out:
#        DT_RECEITA NR_CPF_CANDIDATO  SQ_CANDIDATO  \
# 3462   20/09/2018      37788566349   60000611947
# 3463   17/10/2018      37788566349   60000611947
# 3464   01/11/2018      37788566349   60000611947
# 3465   04/10/2018      37788566349   60000611947
# 3466   09/10/2018      37788566349   60000611947
# 3467   05/10/2018      37788566349   60000611947
# 5412   09/10/2018      13205285115   90000620374
# 5413   22/08/2018      13205285115   90000620374
# 5414   30/11/2018      13205285115   90000620374
# 5415   20/09/2018      13205285115   90000620374
# 5416   26/09/2018      13205285115   90000620374
# 5417   22/08/2018      13205285115   90000620374
# 5418   22/08/2018      13205285115   90000620374
# 5419   19/09/2018      13205285115   90000620374
# 5420   19/09/2018      13205285115   90000620374
# 5421   20/09/2018      13205285115   90000620374
# 5422   29/10/2018      13205285115   90000620374
# 11138  16/08/2018      33096473234  140000606372
# ...

# %%
doacoes_elesmesmos.to_excel('resultados/doacoes/doacoes_proprios_politicos_multas_trabalhistas.xlsx',sheet_name='Sheet1',index=False)

# %%
doacoes_elesmesmos.shape
# Out:
# (23, 17)

# %%
doacoes_elesmesmos['doacoes_tipo'] = 'direta'

# %%
para_site = doacoes_elesmesmos[['VR_RECEITA', 'NR_CPF_CANDIDATO', 'NR_CPF_CNPJ_DOADOR', 'NM_DOADOR_RFB', 'doacoes_tipo', 'DS_FONTE_RECEITA', 'DT_RECEITA']].copy()

# %%
para_site.rename(columns = {'VR_RECEITA':'valor'},inplace = True)
para_site.rename(columns = {'NR_CPF_CANDIDATO':'politico_id'},inplace = True)
para_site.rename(columns = {'NR_CPF_CNPJ_DOADOR':'entidade_id'},inplace = True)
para_site.rename(columns = {'NM_DOADOR_RFB':'entidade_nome'},inplace = True)
para_site.rename(columns = {'DS_FONTE_RECEITA':'origem_do_dinheiro_no_tse'},inplace = True)
para_site.rename(columns = {'DT_RECEITA':'data'},inplace = True)

# %%
para_site.shape
# Out:
# (23, 7)

# %%
para_site.to_csv('resultados/doacoes/doacoes_proprios_politicos_multas_trabalhistas.csv',index=False)

# %%
para_site.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 3462 to 11932
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   valor                      23 non-null     float64
#  1   politico_id                23 non-null     object
#  2   entidade_id                23 non-null     object
#  3   entidade_nome              23 non-null     object
#  4   doacoes_tipo               23 non-null     object
#  5   origem_do_dinheiro_no_tse  23 non-null     object
#  6   data1                      23 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ KB

# %% [markdown]
# ### Multas ambientais

# %%
# Embargos no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
embargos_ibama = pd.read_csv("resultados/embargos_ibama/lista_entidades_embargos_ibama.csv", **kwargs)
embargos_ibama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68162 entries, 0 to 68161
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   municipio          68162 non-null  object
#  1   tipo_infracao      62576 non-null  object
#  2   data_fiscalizacao  68161 non-null  object
#  3   entidade_id        68162 non-null  object
#  4   entidade_nome      68162 non-null  object
#  5   estado_id          68162 non-null  object
#  6   tamanho_area       29827 non-null  object
# dtypes: object(7)
# memory usage: 3.6+ MB

# %%
embargos_ibama
# Out:
#                      municipio  \
# 0            Novo Repartimento
# 1      São Gonçalo do Amarante
# 2                  Paragominas
# 3                    Boa Vista
# 4                    Boa Vista
# ...                        ...
# 68157                    Sinop
# 68158                  Jaguaré
# 68159               Cavalcante
# 68160    São Miguel do Guaporé
# 68161            Alta Floresta
#
#                                            tipo_infracao data_fiscalizacao  \
# 0      Ficam embarcadas todas as atividades na área d...        2019-11-21
# 1      FICA EMBARGADO A ATIVIDADE DE TRANSPORTE DE CA...        2019-11-25
# 2                                                    NaN        2019-11-20
# 3      Ficam embargadas as atividades da empresa em r...        2019-12-06
# 4      Ficam embargadas as atividades da empresa Made...        2019-11-30
# ...                                                  ...               ...
# ...

# %%
empresas_embargos = pd.merge(lista_cnpjs, embargos_ibama.drop_duplicates('entidade_id'), left_on='cnpj', right_on='entidade_id', how = 'left')

# %%
conta = empresas_embargos[pd.notnull(empresas_embargos['tipo_infracao'])].copy()
conta.shape
# Out:
# (7, 12)

# %% [raw]
# conta.columns

# %%
conta
# Out:
#      entidade_id_x                      entidade_nome_x            cnpj  \
# 399    01522833404  PAULO FERNANDO CAVALCANTI DE MORAIS  04094192000101
# 403    01324071320             EVERARDO FERREIRA TELLES  06604714000195
# 546    13205285115                    MAGDA MOFATTO HON  03465317000191
# 578    66296676891           FERNANDO DE CASTRO MARQUES  04636936000164
# 985    32982402300           ANA ANGELICA MOURA SAMPAIO  01619130000170
# 1127   03577163887             JOSE RIBEIRO DE MENDONCA  00819940000107
# 1136   00045741840            FERNANDO ANTONIO FERREIRA  83382721000130
#
#      cnpj_basico cpf_mascarado     municipio  \
# 399     04094192   ***228334**     Rubiataba
# 403     06604714   ***240713**      Itaiçaba
# 546     03465317   ***052851**  Caldas Novas
# 578     04636936   ***966768**      Mineiros
# 985     01619130   ***824023**       Zé Doca
# 1127    00819940   ***771638**   Maurilândia
# 1136    83382721   ***457418**         Vigia
#
# ...

# %%
baixa = conta[['entidade_id_x', 'entidade_nome_x', 'cnpj', 'cpf_mascarado']].copy()

# %%
baixa.rename(columns = {'entidade_id_x':'entidade_id'},inplace = True)
baixa.rename(columns = {'entidade_nome_x':'entidade_nome'},inplace = True)

# %%
baixa['cnpj_basico']= baixa['cnpj'].str[:8]

# %%
baixa[['cnpj_basico', 'cnpj']]
# Out:
#      cnpj_basico            cnpj
# 399     04094192  04094192000101
# 403     06604714  06604714000195
# 546     03465317  03465317000191
# 578     04636936  04636936000164
# 985     01619130  01619130000170
# 1127    00819940  00819940000107
# 1136    83382721  83382721000130

# %%
baixa.columns
# Out:
# Index(['entidade_id', 'entidade_nome', 'cnpj', 'cpf_mascarado', 'cnpj_basico'], dtype='object')

# %%
TextFileReader = pd.read_csv('D://Code//nova_receita//empresas_fev_2022.csv',\
                             chunksize=1000,\
                             sep=',',\
                             converters={'cnpj_basico': lambda x: str(x)},\
                             usecols=['cnpj_basico', 
                                      'razao_social'])

# %%
now = datetime.now()
print("A extração começou às: ", now)

conta = 0
for df in TextFileReader:

    empresas_encontradas = pd.merge(baixa, \
                                 df, \
                                 left_on= 'cnpj_basico', \
                                 right_on='cnpj_basico')
    
    if empresas_encontradas.empty is False:
        if conta == 0:
            df_empresas1 = empresas_encontradas.copy()
        else:
             df_empresas1 = pd.concat([df_empresas1, empresas_encontradas])             
    
        conta = conta + 1
        
now = datetime.now()
print("A extração terminou às: ", now)
# Out:
# A extração começou às:  2022-06-17 11:34:51.745053
# A extração terminou às:  2022-06-17 11:38:43.195627

# %%
df_empresas1.rename(columns = {'razao_social':'cnpj_nome'},inplace = True)
df_empresas1.drop('cnpj_basico', axis=1, inplace=True)

# %%
df_empresas1
# Out:
#    entidade_id                        entidade_nome            cnpj  \
# 0  00045741840            FERNANDO ANTONIO FERREIRA  83382721000130
# 0  03577163887             JOSE RIBEIRO DE MENDONCA  00819940000107
# 0  32982402300           ANA ANGELICA MOURA SAMPAIO  01619130000170
# 0  13205285115                    MAGDA MOFATTO HON  03465317000191
# 0  01522833404  PAULO FERNANDO CAVALCANTI DE MORAIS  04094192000101
# 0  66296676891           FERNANDO DE CASTRO MARQUES  04636936000164
# 0  01324071320             EVERARDO FERREIRA TELLES  06604714000195
#
#   cpf_mascarado                                          cnpj_nome
# 0   ***457418**  ECOMAR INDUSTRIA DE PESCA S/A EM RECUPERACAO J...
# 0   ***771638**                       J. MENDONCA AGROPECUARIA S.A
# 0   ***824023**                              SERRARIA SAMPAIO LTDA
# 0   ***052851**                ROMA EMPREENDIMENTOS E TURISMO LTDA
# 0   ***228334**                         AGRO-RUB AGROPECUARIA LTDA
# ...

# %%
df_empresas1.to_csv('resultados/embargos_ibama/empresas_de_doadores_com_embargos_no_ibama.csv',index=False)

# %%
# Autos de infracao no Ibama

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
autos_ibama = pd.read_csv("resultados/autos_ibama/lista_entidades_autos_de_infracao_ibama.csv", **kwargs)
autos_ibama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525101 entries, 0 to 525100
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   municipio          525096 non-null  object
#  1   tipo_infracao      525101 non-null  object
#  2   data_fiscalizacao  525096 non-null  object
#  3   entidade_id        525101 non-null  object
#  4   entidade_nome      525096 non-null  object
#  5   estado_id          525096 non-null  object
#  6   tamanho_area       32881 non-null   object
#  7   valor              523165 non-null  object
# dtypes: object(8)
# memory usage: 32.0+ MB

# %%
autos_ibama.head()
# Out:
#    municipio                  tipo_infracao    data_fiscalizacao  \
# 0    TRIUNFO  Penalidade pecuniária - Flora  14/05/1998 00:00:00
# 1  PESQUEIRA  Penalidade pecuniária - Flora  18/05/1998 00:00:00
# 2     TRAIRI  Penalidade pecuniária - Flora  16/12/1998 00:00:00
# 3    CAIBATE  Penalidade pecuniária - Flora  10/07/1998 00:00:00
# 4       CRUZ  Penalidade pecuniária - Flora  17/12/1998 00:00:00
#
#       entidade_id                    entidade_nome estado_id tamanho_area  \
# 0     ***065424**             IVALDO GOMES DE LIMA        PE          NaN
# 1     ***890454**          OSVALDO CAMILO DA SILVA        PE          NaN
# 2  69366599000188                   J . O REBOUÇAS        CE          NaN
# 3  75528604000104  AGRICOLA INDUSTRIAL DO SUL LTDA        RS          NaN
# 4  00789473000110               I.M NASCIMENTO  ME        CE          NaN
#
#   valor
# 0   636
# 1   300
# 2   200
# 3   200
# 4   150

# %%
empresas_autos_ibama = pd.merge(lista_cnpjs, autos_ibama.drop_duplicates('entidade_id'), left_on='cnpj', right_on='entidade_id', how = 'left')

# %%
conta = empresas_autos_ibama[pd.notnull(empresas_autos_ibama['tipo_infracao'])].copy()
conta.shape
# Out:
# (50, 13)

# %%
conta.columns
# Out:
# Index(['entidade_id_x', 'entidade_nome_x', 'cnpj', 'cnpj_basico',
#        'cpf_mascarado', 'municipio', 'tipo_infracao', 'data_fiscalizacao',
#        'entidade_id_y', 'entidade_nome_y', 'estado_id', 'tamanho_area',
#        'valor'],
#       dtype='object')

# %%
baixa = conta[['entidade_id_x', 'entidade_nome_x', 'cnpj', 'cnpj_basico', 'cpf_mascarado']].copy()

# %%
baixa.rename(columns = {'entidade_id_x':'entidade_id'},inplace = True)
baixa.rename(columns = {'entidade_nome_x':'entidade_nome'},inplace = True)

# %%
TextFileReader = pd.read_csv('D://Code//nova_receita//empresas_fev_2022.csv',\
                             chunksize=1000,\
                             sep=',',\
                             converters={'cnpj_basico': lambda x: str(x)},\
                             usecols=['cnpj_basico', 
                                      'razao_social'])

# %%
now = datetime.now()
print("A extração começou às: ", now)

conta = 0
for df in TextFileReader:

    empresas_encontradas = pd.merge(baixa, \
                                 df, \
                                 left_on= 'cnpj_basico', \
                                 right_on='cnpj_basico')
    
    if empresas_encontradas.empty is False:
        if conta == 0:
            df_empresas1 = empresas_encontradas.copy()
        else:
             df_empresas1 = pd.concat([df_empresas1, empresas_encontradas])             
    
        conta = conta + 1
        
now = datetime.now()
print("A extração terminou às: ", now)
# Out:
# A extração começou às:  2022-06-17 11:41:22.841210
# A extração terminou às:  2022-06-17 11:45:21.141063

# %%
df_empresas1.rename(columns = {'razao_social':'cnpj_nome'},inplace = True)
df_empresas1.drop('cnpj_basico', axis=1, inplace=True)

# %%
df_empresas1.head()
# Out:
#    entidade_id                       entidade_nome            cnpj  \
# 0  38380196953            JAIME MAXIMINO BAGATTOLI  63745228000120
# 0  42931550663                 ADAO RIBEIRO SOARES  64481450000126
# 0  39727254934                    WALTER SCHLATTER  70355771000187
# 0  00585831904                       ASSIS GURGACZ  76080738000178
# 0  52141489849  LINCOLN LAFAIETE DA SILVEIRA BUENO  83318790000185
#
#   cpf_mascarado                                          cnpj_nome
# 0   ***801969**                        TRANSPORTADORA GIOMILA LTDA
# 0   ***315506**                   TRANSPORTE RIBEIRO E SOARES LTDA
# 0   ***272549**  AGRO BOLSAO ARMAZENS GERAIS COMERCIO DE CEREAI...
# 0   ***858319**  EUCATUR-EMPRESA UNIAO CASCAVEL DE TRANSPORTES ...
# 0   ***414898**                    MAFRIPAR BRANDS MANAGEMENT LTDA

# %%
df_empresas1.to_csv('resultados/autos_ibama/empresas_de_doadores_com_autos_no_ibama.csv',index=False)

# %%
# Autos ICMBIO

# %%
kwargs = {'sep': ',', 'dtype': str, 'encoding': 'utf-8'}
autos_icmbio = pd.read_csv("resultados/autos_icmbio/lista_entidades_autos_icmbio.csv", **kwargs)
autos_icmbio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1882 entries, 0 to 1881
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   municipio          1882 non-null   object
#  1   tipo_infracao      1855 non-null   object
#  2   data_fiscalizacao  1882 non-null   object
#  3   entidade_id        1882 non-null   object
#  4   entidade_nome      1882 non-null   object
#  5   estado_id          1882 non-null   object
#  6   valor_multa        1862 non-null   object
# dtypes: object(7)
# memory usage: 103.0+ KB

# %%
autos_icmbio.head()
# Out:
#                 municipio                                      tipo_infracao  \
# 0               Palmeiras                                                NaN
# 1  Jijoca de Jericoacoara  realizar serviÃ§o comercial " passeio de quadr...
# 2                  Parati                                                NaN
# 3             Porto Velho  Destruir 58,7062 hectares de floresta nativa, ...
# 4                  Parati  Causar dano a Ãrea de ProteÃ§Ã£o Ambiental de...
#
#   data_fiscalizacao     entidade_id                            entidade_nome  \
# 0        2020-10-13     30989388115              Luiz Oscar Marques Ferreira
# 1        2021-02-25  31753302000164    Francisco Alcenir  Rodrigues de Souza
# 2        2019-10-01  22327400000149  CIDADE JARDIM COMERCIO DE MADEIRAS LTDA
# 3        2020-04-07     15813798897      Luiz Felipe Grava do Val Nascimento
# 4        2021-03-05     04701852872                          Vilson Predolim
#
#   estado_id valor_multa
# ...

# %%
empresas_autos_icmbio = pd.merge(lista_cnpjs, autos_icmbio.drop_duplicates('entidade_id'), left_on='cnpj', right_on='entidade_id', how = 'left')

# %%
conta = empresas_autos_ibama[pd.notnull(empresas_autos_ibama['tipo_infracao'])].copy()
conta.shape
# Out:
# (50, 13)

# %%
conta.columns
# Out:
# Index(['entidade_id_x', 'entidade_nome_x', 'cnpj', 'cnpj_basico',
#        'cpf_mascarado', 'municipio', 'tipo_infracao', 'data_fiscalizacao',
#        'entidade_id_y', 'entidade_nome_y', 'estado_id', 'tamanho_area',
#        'valor'],
#       dtype='object')

# %%
baixa = conta[['entidade_id_x', 'entidade_nome_x', 'cnpj', 'cnpj_basico', 'cpf_mascarado']].copy()

# %%
baixa.rename(columns = {'entidade_id_x':'entidade_id'},inplace = True)
baixa.rename(columns = {'entidade_nome_x':'entidade_nome'},inplace = True)

# %%
TextFileReader = pd.read_csv('D://Code//nova_receita//empresas_fev_2022.csv',\
                             chunksize=1000,\
                             sep=',',\
                             converters={'cnpj_basico': lambda x: str(x)},\
                             usecols=['cnpj_basico', 
                                      'razao_social'])

# %%
now = datetime.now()
print("A extração começou às: ", now)

conta = 0
for df in TextFileReader:

    empresas_encontradas = pd.merge(baixa, \
                                 df, \
                                 left_on= 'cnpj_basico', \
                                 right_on='cnpj_basico')
    
    if empresas_encontradas.empty is False:
        if conta == 0:
            df_empresas1 = empresas_encontradas.copy()
        else:
             df_empresas1 = pd.concat([df_empresas1, empresas_encontradas])             
    
        conta = conta + 1
        
now = datetime.now()
print("A extração terminou às: ", now)
# Out:
# A extração começou às:  2022-06-17 11:52:33.664074
# A extração terminou às:  2022-06-17 11:56:29.619397

# %%
df_empresas1.rename(columns = {'razao_social':'cnpj_nome'},inplace = True)
df_empresas1.drop('cnpj_basico', axis=1, inplace=True)

# %%
df_empresas1.head()
# Out:
#    entidade_id                       entidade_nome            cnpj  \
# 0  38380196953            JAIME MAXIMINO BAGATTOLI  63745228000120
# 0  42931550663                 ADAO RIBEIRO SOARES  64481450000126
# 0  39727254934                    WALTER SCHLATTER  70355771000187
# 0  00585831904                       ASSIS GURGACZ  76080738000178
# 0  52141489849  LINCOLN LAFAIETE DA SILVEIRA BUENO  83318790000185
#
#   cpf_mascarado                                          cnpj_nome
# 0   ***801969**                        TRANSPORTADORA GIOMILA LTDA
# 0   ***315506**                   TRANSPORTE RIBEIRO E SOARES LTDA
# 0   ***272549**  AGRO BOLSAO ARMAZENS GERAIS COMERCIO DE CEREAI...
# 0   ***858319**  EUCATUR-EMPRESA UNIAO CASCAVEL DE TRANSPORTES ...
# 0   ***414898**                    MAFRIPAR BRANDS MANAGEMENT LTDA

# %%
df_empresas1.to_csv('resultados/autos_icmbio/empresas_de_doadores_com_autos_no_icmbio.csv',index=False)
